# %%
import shutil
import os

# %%
shutil.rmtree('/Users/wenglongao/Downloads/未命名文件夹 3')
os.mkdir('/Users/wenglongao/Downloads/未命名文件夹 3')

# %%
from lwpackage.lwutils.file_processor import move_file, make_path, clear_path

# %%
from lwpackage.lwutils.lwpath import PREPROCESS_PHOTO_PATH, POSTPROCESS_PHOTO_PATH, FOLDER_TO_ALBUM_MAP

# %%
clear_path(PREPROCESS_PHOTO_PATH)

# %%
import akshare as ak

# %%
import akshare as ak

stock_zh_a_hist_df = ak.stock_zh_a_hist(symbol="000001", start_date="20210101", end_date="20211231", adjust="")
print(stock_zh_a_hist_df)

# %%
stock_zh_a_hist_df

# %%
df = ak.stock_zh_a_tick_tx(symbol="000001", trade_date="20211101")
df

# %%
stock_zh_a_minute_df = ak.stock_zh_a_hist(symbol='600751', period='1', adjust="qfq")
stock_zh_a_minute_df

# %%
stock_zh_a_minute_df

# %%
df_stock = ak.stock_zh_a_spot_em()

# %%
ak.stock_zh_a_minute(symbol='sz000001', period='1', adjust="qfq")

# %%
df_stock

# %%
import akshare as ak

# 获取平安银行(000001)的股票代码
df = ak.stock_zh_a_spot_em()
symbol = df[df['名称'] == '平安银行']['代码'].values[0]
print(symbol)

# %%
df = ak.stock_zh_a_hist(symbol="000001", period="daily", start_date="20170301", end_date='20210907', adjust="")
df

# %%
# 不加symbol默认返回中国平安
df = ak.stock_zh_a_hist(period="daily", start_date="20170301", end_date='20210907', adjust="")
df

# %%
df = ak.stock_zh_a_hist(symbol="000001", period="daily", start_date="20170301", end_date='20210907', adjust="")
df

# %%
import akshare as ak

# 注意：该接口返回的数据只有最近一个交易日的有开盘价，其他日期开盘价为 0
stock_zh_a_hist_min_em_df = ak.stock_zh_a_hist_min_em(symbol="300429", start_date="2023-11-01 09:32:00", end_date="2023-11-02 09:32:00", period='1', adjust='')
stock_zh_a_hist_min_em_df

# %%
# 注意，akshare中的一些函数需要输入带有市场标识的股票

# %%
df_stock[df_stock['代码'] == '000001']

# %%
def add_market_prefix(code: str) -> str:
    if code.startswith(('0', '3')):
        return 'sz' + code
    elif code.startswith('6'):
        return 'sh' + code
    else:
        raise ValueError(f"Invalid A股股票代码: {code}")

# %%
add_market_prefix('300269')

# %%
ak.stock_zh_a_minute(symbol='sz300269', period='1', adjust="qfq")

# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import backtrader as bt

if __name__ == '__main__':
    
    # 创建Cerebro实例
    cerebro = bt.Cerebro()
#     cerebro.broker.setcash(100000.0)

    # 输出Cerebro引擎默认本金
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # 运行引擎
    cerebro.run()

    # 输出Cerebro引擎运行之后本金情况
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())

# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import backtrader as bt

if __name__ == '__main__':
    cerebro = bt.Cerebro()
    cerebro.broker.setcash(100000.0) # 设置本金

    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    cerebro.run()

    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())

# %%
os.path.abspath(sys.argv[0])

# %%
sys.argv[0]

# %%
modpath = os.path.dirname(os.path.abspath(sys.argv[0]))
datapath = os.path.join(modpath, '../../datas/orcl-1995-2014.txt')

# %%
datapath

# %%
data = bt.feeds.YahooFinanceCSVData(
       dataname=datapath,
       # Do not pass values before this date
       fromdate=datetime.datetime(2000, 1, 1),
       # Do not pass values after this date
       todate=datetime.datetime(2000, 12, 31),
       reverse=False)

# %%
import os
import sys
from datetime import datetime
import pandas as pd
import akshare as ak

# %%
df = ak.stock_zh_a_minute(symbol='sz000001', period='1', adjust="qfq")

# %%
df = df.rename(columns={'day': 'datetime'})

# %%
df['volume'] = df['volume'].astype(int)

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df.dtypes
# Out:
# datetime    datetime64[ns]
# open               float64
# high               float64
# low                float64
# close              float64
# volume               int64
# dtype: object

# %%
df
# Out:
#                 datetime   open   high    low  close   volume
# 0    2023-10-24 13:53:00  10.55  10.59  10.55  10.58  1562200
# 1    2023-10-24 13:54:00  10.57  10.60  10.57  10.60  1539663
# 2    2023-10-24 13:55:00  10.59  10.60  10.59  10.59   338000
# 3    2023-10-24 13:56:00  10.59  10.61  10.58  10.61  1019300
# 4    2023-10-24 13:57:00  10.60  10.60  10.58  10.59   216600
# ...                  ...    ...    ...    ...    ...      ...
# 1965 2023-11-03 14:54:00  10.46  10.46  10.45  10.46   282200
# 1966 2023-11-03 14:55:00  10.45  10.47  10.45  10.46   722900
# 1967 2023-11-03 14:56:00  10.46  10.47  10.45  10.46   137400
# 1968 2023-11-03 14:57:00  10.46  10.47  10.46  10.46   411500
# 1969 2023-11-03 15:00:00  10.48  10.48  10.48  10.48  1529300
#
# [1970 rows x 6 columns]

# %% [markdown]
# `bt.Strategy`类是Backtrader中用于制定回测策略的核心类。以下是一些常用的属性：
#
# 1. `self.datas`：包含所有数据源的列表。每个数据源都是一个`bt.feeds`对象，包含有关数据的信息，例如开盘价、收盘价等。
#
# 2. `self.params`：包含策略参数的字典。这些参数可以在实例化策略时传递，并在策略中使用。
#
# 3. `self.position`：包含当前持仓的信息。这是一个`bt.Position`对象，其中包含有关持仓数量、平均成本等的信息。
#
# 4. `self.broker`：包含有关经纪人的信息。这是一个`bt.broker`对象，其中包含有关现金余额、手续费等的信息。
#
# 5. `self.order`：包含有关当前订单的信息。这是一个`bt.Order`对象，其中包含有关订单类型、数量等的信息。
#
# 6. `self.trade`：包含有关当前交易的信息。这是一个`bt.Trade`对象，其中包含有关交易类型、数量等的信息。
#
# 7. `self.analyzers`：包含所有分析器的列表。每个分析器都是一个`bt.analyzers`对象，用于计算策略性能指标，例如收益率、夏普比率等。
#
# 希望这可以帮助您解决问题。如果您需要更多帮助，请告诉我。
#
# 源: 与必应的对话， 2023/11/2
# (1) Strategy - Backtrader. https://www.backtrader.com/docu/strategy/.
# (2) Python量化交易学习笔记（23）——backtrader的Strategy类 .... https://blog.csdn.net/m0_46603114/article/details/105488437.
# (3) Can you add parameters to backtrader strategy? - Stack Overflow. https://stackoverflow.com/questions/72273407/can-you-add-parameters-to-backtrader-strategy.

# %%
from __future__ import (absolute_import, division, print_function,
                       unicode_literals)

import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])

# Import the backtrader platform
import backtrader as bt

# Create a Strategy
class TestStrategy(bt.Strategy):

    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = self.datas[0].datetime.date()
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close
    
    # 在回测过程中，next()方法将在每个数据点上被调用一次，以便策略可以评估新数据并执行交易。
    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])


class MyStrategy(bt.Strategy):
    def __init__(self):
        self.sma = bt.indicators.SimpleMovingAverage(self.data, period=15)

    def next(self):
        if self.data.close > self.sma:
            self.buy()
            # 我们只传入了一个数据源df，因此self.datas只有一个元素。
            print(f'type of self.datas is {type(self.datas)}')  # self.datas是一个list
            print(f'type of self.datas[0] is {type(self.datas[0])}') # self.datas[0]是一个bt.feeds
            print(self.datas[0].datetime.datetime())
            print(f'{self.datas[0].close[0]}, {self.datas[0].close[-1]}, {self.datas[0].close[-2]}, {self.sma[0]}')
        elif self.data.close < self.sma:
            self.sell()
            
# Create a Strategy
class TestStrategy1(bt.Strategy):

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])

        if self.dataclose[0] < self.dataclose[-1]:
            # current close less than previous close

            if self.dataclose[-1] < self.dataclose[-2]:
                # previous close less than the previous close

                # BUY, BUY, BUY!!! (with all possible default parameters)
                self.log(f'BUY CREATE, {self.dataclose[0]}')
                # 订单是在“市场上”执行的，代理(Cerebro实例)使用下一个bar的开盘价执行买操作，
                # 因为它是当前检查bar之后的第一个tick（满足下单条件之后的下一个bar中的开盘价-强调一下，
                # 这里未必是下一个开盘日，因为backtrader没有假设你的数据采样间隔是D）
                self.buy()
                

class TestStrategy2(bt.Strategy):
    
    # log函数主要目的就是输出时间
    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.datetime(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close

        # To keep track of pending orders
        self.order = None

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, %.2f' % order.executed.price)
            elif order.issell():
                self.log('SELL EXECUTED, %.2f' % order.executed.price)

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        # Write down: no pending order
        self.order = None

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])

        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return
#         print(self.position)
        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if ...
            if self.dataclose[0] < self.dataclose[-1]:
                    # current close less than previous close

                    if self.dataclose[-1] < self.dataclose[-2]:
                        # previous close less than the previous close

                        # BUY, BUY, BUY!!! (with default parameters)
                        self.log('BUY CREATE, %.2f' % self.dataclose[0])

                        # Keep track of the created order to avoid a 2nd order
                        self.order = self.buy()

        else:

            # Already in the market ... we might sell
            if len(self) >= (self.bar_executed + 5):
                print('lenself:', len(self))
                print('bar:', self.bar_executed)
                # SELL, SELL, SELL!!! (with all possible default parameters)
                self.log('SELL CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell(size=100)


# Create a Stratey
class TestStrategy3(bt.Strategy):

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = self.datas[0].datetime.datetime(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close
            
        # 注意，本身bt.Strategy没有order属性。这里的self.order是我们自己定义的
        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None

    def notify_order(self, order):
        # 注意到在传入数据的每一个tick，notify_order可能会被调用多次，即订单状态改变一次，notify_order就会被调用一次
        print('在一次订单状态改变时都会调用notify_order函数')
        print('order.status:', order.status, order.getstatusname())
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed，此时order.getstatusname() = Completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():  # 如果是买单，输出BUY EXECUTED的log
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # 如果是卖单，输出SELL EXECUTED的log
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None

    def notify_trade(self, trade):
        print('在一次交易状态改变时都会调用notify_trade函数')
        if not trade.isclosed:
            return
        
        self.log('OPERATION PROFIT: GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])
        print('self.order: ', self.order)
        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if ...
            if self.dataclose[0] < self.dataclose[-1]:
                    # current close less than previous close

                    if self.dataclose[-1] < self.dataclose[-2]:
                        # previous close less than the previous close

                        # BUY, BUY, BUY!!! (with default parameters)
                        self.log('BUY CREATE, %.2f' % self.dataclose[0])

                        # Keep track of the created order to avoid a 2nd order
                        self.order = self.buy()

        else:

            # Already in the market ... we might sell
            if len(self) >= (self.bar_executed + 5):
                # SELL, SELL, SELL!!! (with all possible default parameters)
                self.log('SELL CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell()

    
if __name__ == '__main__':
   # Create a cerebro entity
    cerebro = bt.Cerebro()
    
    # Add a strategy
#     cerebro.addstrategy(TestStrategy)
#     cerebro.addstrategy(MyStrategy)
#     cerebro.addstrategy(TestStrategy1)
#     cerebro.addstrategy(TestStrategy2)
    cerebro.addstrategy(TestStrategy3)

    data = bt.feeds.PandasData(dataname=df, datetime=-1)

    # Add the Data Feed to Cerebro
    # 每次传入的数据保存在Strategy的data中,使用self.datas调用。
    # 我们只传入了一次数据，则self.datas只包含一个元素，调用的时候使用self.datas[0]
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(100000.0)
    
    # 设置佣金，我们要在每次买卖操作的时候给0.1%的佣金率
    # 0.1% ... divide by 100 to remove the %
    cerebro.broker.setcommission(commission=0.001)

    
    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
#     cerebro.plot(style='bar')
# Out:
# Starting Portfolio Value: 100000.00
# 2023-10-24T13:53:00, Close, 10.58
# self.order:  None
# 2023-10-24T13:54:00, Close, 10.60
# self.order:  None
# 2023-10-24T13:55:00, Close, 10.59
# self.order:  None
# 2023-10-24T13:56:00, Close, 10.61
# self.order:  None
# 2023-10-24T13:57:00, Close, 10.59
# self.order:  None
# 2023-10-24T13:58:00, Close, 10.57
# self.order:  None
# 2023-10-24T13:58:00, BUY CREATE, 10.57
# 在一次订单状态改变时都会调用notify_order函数
# order.status: 1 Submitted
# 在一次订单状态改变时都会调用notify_order函数
# order.status: 2 Accepted
# 在一次订单状态改变时都会调用notify_order函数
# order.status: 4 Completed
# 2023-10-24T13:59:00, BUY EXECUTED, Price: 10.57, Cost: 10.57, Comm 0.01
# 在一次交易状态改变时都会调用notify_trade函数
# 2023-10-24T13:59:00, Close, 10.56
# self.order:  None
# 2023-10-24T14:00:00, Close, 10.57
# self.order:  None
# 2023-10-24T14:01:00, Close, 10.58
# self.order:  None
# 2023-10-24T14:02:00, Close, 10.59
# self.order:  None
# 2023-10-24T14:03:00, Close, 10.61
# self.order:  None
# ...

# %% [markdown]
# #### 自定义参数调参

# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)

import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])

# Import the backtrader platform
import backtrader as bt


# Create a Stratey
class TestStrategy(bt.Strategy):
    # 其实就是定义了一个TestStrategy的类参数，这里的wla也是类参数。
    # 定义成params名称，用tuple类型存放就可以用self.params.exitbars这种方法方便地调用
    params = (
        ('exitbars', 5),
    )
    wla = 'wla'

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close

        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])

        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if ...
            if self.dataclose[0] < self.dataclose[-1]:
                    # current close less than previous close

                    if self.dataclose[-1] < self.dataclose[-2]:
                        # previous close less than the previous close

                        # BUY, BUY, BUY!!! (with default parameters)
                        self.log('BUY CREATE, %.2f' % self.dataclose[0])

                        # Keep track of the created order to avoid a 2nd order
                        self.order = self.buy()

        else:

            # Already in the market ... we might sell
            if len(self) >= (self.bar_executed + self.params.exitbars):
#                 print('self.params: ', self.params)
                print('self.params.exitbars: ', self.params.exitbars)
                print('self.wla: ', self.wla)
                # SELL, SELL, SELL!!! (with all possible default parameters)
                self.log('SELL CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell()
                

class TestStrategy2(bt.Strategy):
    params = (
        ('maperiod', 15),
    )

    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close

        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None

        # Add a MovingAverageSimple indicator
        self.sma = bt.indicators.SimpleMovingAverage(
            self.datas[0], period=self.params.maperiod)

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def next(self):
        # Simply log the closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])

        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # Not yet ... we MIGHT BUY if ...
            if self.dataclose[0] > self.sma[0]:

                # BUY, BUY, BUY!!! (with all possible default parameters)
                self.log('BUY CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.buy()

        else:

            if self.dataclose[0] < self.sma[0]:
                # SELL, SELL, SELL!!! (with all possible default parameters)
                self.log('SELL CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell()


if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
#     cerebro.addstrategy(TestStrategy)
    cerebro.addstrategy(TestStrategy2)

    data = bt.feeds.PandasData(dataname=df, datetime=-1)

    # Add the Data Feed to Cerebro
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(100000.0)

    # Add a FixedSize sizer according to the stake
    cerebro.addsizer(bt.sizers.FixedSize, stake=10)

    # Set the commission - 0.1% ... divide by 100 to remove the %
    cerebro.broker.setcommission(commission=0.001)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 100000.00
# 2023-10-24, Close, 10.60
# 2023-10-24, BUY CREATE, 10.60
# 2023-10-24, BUY EXECUTED, Price: 10.60, Cost: 106.00, Comm 0.11
# 2023-10-24, Close, 10.61
# 2023-10-24, Close, 10.60
# 2023-10-24, Close, 10.59
# 2023-10-24, SELL CREATE, 10.59
# 2023-10-24, SELL EXECUTED, Price: 10.59, Cost: 106.00, Comm 0.11
# 2023-10-24, OPERATION PROFIT, GROSS -0.10, NET -0.31
# 2023-10-24, Close, 10.59
# 2023-10-24, Close, 10.60
# 2023-10-24, BUY CREATE, 10.60
# 2023-10-24, BUY EXECUTED, Price: 10.60, Cost: 106.00, Comm 0.11
# 2023-10-24, Close, 10.60
# 2023-10-24, Close, 10.60
# 2023-10-24, Close, 10.61
# 2023-10-24, Close, 10.59
# 2023-10-24, SELL CREATE, 10.59
# 2023-10-24, SELL EXECUTED, Price: 10.59, Cost: 106.00, Comm 0.11
# 2023-10-24, OPERATION PROFIT, GROSS -0.10, NET -0.31
# 2023-10-24, Close, 10.59
# 2023-10-24, Close, 10.59
# 2023-10-24, Close, 10.58
# 2023-10-24, Close, 10.58
# 2023-10-24, Close, 10.58
# 2023-10-24, Close, 10.59
# ...

# %%
df
# Out:
#                 datetime   open   high    low  close   volume
# 0    2023-10-24 13:53:00  10.55  10.59  10.55  10.58  1562200
# 1    2023-10-24 13:54:00  10.57  10.60  10.57  10.60  1539663
# 2    2023-10-24 13:55:00  10.59  10.60  10.59  10.59   338000
# 3    2023-10-24 13:56:00  10.59  10.61  10.58  10.61  1019300
# 4    2023-10-24 13:57:00  10.60  10.60  10.58  10.59   216600
# ...                  ...    ...    ...    ...    ...      ...
# 1965 2023-11-03 14:54:00  10.46  10.46  10.45  10.46   282200
# 1966 2023-11-03 14:55:00  10.45  10.47  10.45  10.46   722900
# 1967 2023-11-03 14:56:00  10.46  10.47  10.45  10.46   137400
# 1968 2023-11-03 14:57:00  10.46  10.47  10.46  10.46   411500
# 1969 2023-11-03 15:00:00  10.48  10.48  10.48  10.48  1529300
#
# [1970 rows x 6 columns]

# %%
df = df.sort_values(by='datetime')
df
# Out:
#                 datetime   open   high    low  close   volume
# 0    2023-10-24 13:53:00  10.55  10.59  10.55  10.58  1562200
# 1    2023-10-24 13:54:00  10.57  10.60  10.57  10.60  1539663
# 2    2023-10-24 13:55:00  10.59  10.60  10.59  10.59   338000
# 3    2023-10-24 13:56:00  10.59  10.61  10.58  10.61  1019300
# 4    2023-10-24 13:57:00  10.60  10.60  10.58  10.59   216600
# ...                  ...    ...    ...    ...    ...      ...
# 1965 2023-11-03 14:54:00  10.46  10.46  10.45  10.46   282200
# 1966 2023-11-03 14:55:00  10.45  10.47  10.45  10.46   722900
# 1967 2023-11-03 14:56:00  10.46  10.47  10.45  10.46   137400
# 1968 2023-11-03 14:57:00  10.46  10.47  10.46  10.46   411500
# 1969 2023-11-03 15:00:00  10.48  10.48  10.48  10.48  1529300
#
# [1970 rows x 6 columns]

# %%
class MyStrategy(bt.Strategy):
    def __init__(self):
        self.sma = bt.indicators.SimpleMovingAverage(self.data, period=15)

    def next(self):
        if self.data.close > self.sma:
            self.buy()
            print(f'{self.sma}')
        elif self.data.close < self.sma:
            self.sell()

# %% [markdown]
# `self.datas`是Backtrader中的一个属性，它是一个包含所有数据源的列表。每个数据源都是一个`bt.feeds`对象，包含有关数据的信息，例如开盘价、收盘价等。您可以使用以下代码从`self.datas`中获取数据：
#
# ```python
# data = self.datas[0]
# ```
#
# 这将返回第一个数据源。如果您有多个数据源，您可以使用不同的索引来访问它们。例如，要访问第二个数据源，您可以使用以下代码：
#
# ```python
# data = self.datas[1]
# ```
#
# 一旦您获得了数据源，您就可以使用它来执行各种操作，例如计算指标、生成信号等。
#
# 希望这可以帮助您解决问题。如果您需要更多帮助，请告诉我。
#
# 源: 与必应的对话， 2023/11/2
# (1) Backtrader来啦：数据篇-腾讯云开发者社区-腾讯云. https://cloud.tencent.com/developer/article/1820100.
# (2) backtrader教程（三）- 单（多）股票策略篇 - 知乎. https://zhuanlan.zhihu.com/p/402559960.
# (3) Data Feeds - Backtrader. https://www.backtrader.com/docu/datafeed/.

# %% [markdown]
# 要在Backtrader中传入多个数据源，您可以使用以下代码：
#
# ```python
# data1 = bt.feeds.PandasData(dataname=dataframe1)
# data2 = bt.feeds.PandasData(dataname=dataframe2)
# cerebro.adddata(data1)
# cerebro.adddata(data2)
# ```
#
# 这将创建两个数据源`data1`和`data2`，并将它们添加到Backtrader引擎中。请注意，您需要为每个数据源创建一个`bt.feeds`对象，并将其传递给`cerebro.adddata()`方法。
#
# 在这里，我们假设您有两个Pandas DataFrame对象`dataframe1`和`dataframe2`，它们包含您要回测的数据。您可以使用这些数据源来执行各种操作，例如计算指标、生成信号等。
#
# 希望这可以帮助您解决问题。如果您需要更多帮助，请告诉我。
#
# 源: 与必应的对话， 2023/11/2
# (1) Using Multiple Datasets in Backtrader’s Strategies. https://quantnomad.com/using-multiple-datasets-in-backtraders-strategies/.
# (2) Running Backtesting for Universe of Stocks in Python with Backtrader .... https://quantnomad.com/running-backtesting-for-universe-of-stocks-in-python-with-backtrader/.
# (3) Multiple Data Strategy - Backtrader. https://www.backtrader.com/blog/posts/2015-09-03-multidata-strategy/multidata-strategy/.
# (4) Multi-Data Example - Backtrader. https://www.backtrader.com/blog/posts/2017-04-09-multi-example/multi-example/.

# %% [markdown]
# 要访问`self.datas[0]`中的`close`，您可以使用以下代码：
#
# ```python
# data = self.datas[0]
# close_price = data.close[0]
# ```
#
# 这将返回第一个数据源的最新收盘价。如果您想访问之前的收盘价，只需将索引更改为所需的位置即可。
#
# 希望这可以帮助您解决问题。如果您需要更多帮助，请告诉我。
#
# 源: 与必应的对话， 2023/11/2
# (1) Backtrader来啦：数据篇-腾讯云开发者社区-腾讯云. https://cloud.tencent.com/developer/article/1820100.
# (2) Difference between self.data and self.datas in Strategy | Backtrader .... https://community.backtrader.com/topic/5226/difference-between-self-data-and-self-datas-in-strategy.
# (3) Backtrader（五）- 策略常用对象_self.position = get_pos-CSDN博客. https://blog.csdn.net/weixin_44785098/article/details/122522121.
# (4) Backtrader系列教程②:数据篇_bt.feeds.pandasdata-CSDN博客. https://blog.csdn.net/qq_41578115/article/details/122529156.
# (5) Platform Concepts - Backtrader. https://www.backtrader.com/docu/concepts/.

# %% [markdown]
# `self.bar_executed`是Backtrader中的一个属性，它记录了在订单相关通知发出时数据源的长度。具体来说，它记录了在订单相关通知发出时数据源中的条目数。例如，如果您的数据源包含100个条目，并且在第50个条目处发出了订单相关通知，则`self.bar_executed`将为50。
#
# 您可以使用`self.bar_executed`来确定订单何时被执行。例如，如果您想在订单执行后打印一条消息，则可以使用以下代码：
#
# ```python
# class MyStrategy(bt.Strategy):
#     def notify_order(self, order):
#         if order.status in [order.Completed]:
#             self.log('Order executed at {}'.format(self.datas[0].datetime.date()))
#             self.log('Bars executed: {}'.format(self.bar_executed))
# ```
#
# 在这里，我们定义了一个名为`MyStrategy`的策略，并在`notify_order()`方法中使用了`self.bar_executed`来获取已执行的数据源条目数。请注意，只有当订单状态为已完成时，才会打印消息。
#
# 希望这可以帮助您解决问题。如果您需要更多帮助，请告诉我。
#
# 源: 与必应的对话， 2023/11/2
# (1) I wonder What self.bar_executed means?? - Backtrader Community. https://community.backtrader.com/topic/2422/i-wonder-what-self-bar_executed-means.
# (2) Orders - Creation/Execution - Backtrader. https://www.backtrader.com/docu/order-creation-execution/order-creation-execution/.
# (3) Backtrader: How can I have stops execute on the same bar they were .... https://stackoverflow.com/questions/75242615/backtrader-how-can-i-have-stops-execute-on-the-same-bar-they-were-entered-on.
# (4) Python回测神器-Backtrader（中） - 知乎. https://zhuanlan.zhihu.com/p/262068794.

# %% [markdown]
# 在backtrader中，strategy是一个类，它定义了交易策略的逻辑和参数。len(self)是一个方法，它返回当前策略处理过的数据（bar）的数量²。也就是说，len(self)表示策略从开始运行到现在，接收到了多少个数据点。
#
# len(self)的值和数据表格中的索引值可能不一致，有两种可能的原因³：
#
# 1. 回测开始时间和数据表格开始时间不一致。比如，数据表格从2020年1月1日开始，但是回测从2020年6月1日开始，那么len(self)的值会比数据表格的索引值小6个月的数据量。
# 2. 使用了移动平均线等有最小周期的指标。比如，使用了20日移动平均线，那么策略需要至少20个数据点才能计算出第一个移动平均值，所以len(self)的值会比数据表格的索引值小20。
#
# 希望这能回答你的问题。如果你还有其他关于backtrader的问题，欢迎继续提问。😊
#
# 源: 与必应的对话， 2023/11/4
# (1) backtrader 中，next（）里面，len（self）的值为什么和我 .... https://www.zhihu.com/question/525069122.
# (2) backtrader学习（一） 策略执行顺序 - CSDN博客. https://blog.csdn.net/czttcztt/article/details/121978185.
# (3) 量化框架backtrader中文翻译之第一个策略(3) - 知乎. https://zhuanlan.zhihu.com/p/148937038.

# %% [markdown]
# len(self)和self.bar_executed的值都是用来表示backtrader中处理过的数据（bar）的数量的。但是，它们之间有一些区别：
#
# - len(self)是一个内置函数，它返回一个对象的长度。在backtrader中，len(self)返回策略对象的长度，也就是它已经接收到的数据的数量。len(self)的值会随着每个新的数据点而增加。
# - self.bar_executed是一个策略对象的属性，它记录了最后一次执行订单的数据索引。self.bar_executed的值只有在订单被执行时才会更新，否则保持不变。
#
# 因此，len(self)和self.bar_executed的值可能相同，也可能不同，这取决于数据是否被预加载，以及订单是否被执行。²³
#
# 如果您想了解更多关于backtrader的知识，您可以参考这篇文章⁴，它详细解析了Python中的self的含义和用法。希望这对您有所帮助。👍
#
# 源: 与必应的对话， 2023/11/4
# (1) backtrader line长度，已经处理过多少条 - CSDN博客. https://blog.csdn.net/silence_pinot/article/details/125636337.
# (2) backtrader 中，next（）里面，len（self）的值为什么和我 .... https://www.zhihu.com/question/525069122.
# (3) Python中的self详细解析 - 知乎. https://zhuanlan.zhihu.com/p/356325860.
# (4) Python量化交易学习笔记（10）——第一个策略回测程序 .... https://blog.csdn.net/m0_46603114/article/details/104972859.

# %% [markdown]
# `notify_trade` 方法是 `Backtrader` 中的一个回调函数，它会在交易状态发生变化时被调用 ². 该方法的默认实现会在交易关闭时打印出交易的毛收益、扣佣后收益和佣金 ²³.
#
# 如果您想自定义 `notify_trade` 方法，可以在您的策略类中重写该方法。例如，您可以在交易关闭时记录交易的盈利情况，如下所示：
#
# ```python
# class MyStrategy(bt.Strategy):
#     def notify_trade(self, trade):
#         if trade.isclosed:
#             print('毛收益 %0.2f, 扣佣后收益 % 0.2f, 佣金 %.2f' % (trade.pnl, trade.pnlcomm, trade.commission))
# ```
#
# 在上述代码中，我们重写了 `notify_trade` 方法，当交易关闭时，会打印出交易的毛收益、扣佣后收益和佣金 ².
#
# 如果您想了解更多关于 `Backtrader` 的信息，可以参考这篇文章 ¹.
#
# 源: 与必应的对话， 2023/11/4
# (1) backtrader中何为一个交易trade?你可能并没理解它 - CSDN博客. https://blog.csdn.net/qtbgo/article/details/109799469.
# (2) backtrader中何为一个交易trade?你可能并没理解它。 - 知乎. https://zhuanlan.zhihu.com/p/299630905.
# (3) 量化投资之工具篇：Backtrader从入门到精通（5）Strategy .... https://zhuanlan.zhihu.com/p/464114946.
# (4) backtrader源码解读 (6)：策略 - 知乎. https://zhuanlan.zhihu.com/p/621758956.

# %% [markdown]
# `trade.isclosed` 是 `Backtrader` 中的一个属性，它记录了交易是否已经关闭 ¹. 当交易的仓位从正值变为0时，该交易会被关闭，此时 `trade.isclosed` 会被设置为 `True` ¹².
#
# 例如，假设您在 `Backtrader` 中进行了一次交易，开仓价格为 `100`，平均价格为 `110`，数量为 `10`，佣金为 `5`，则该交易的毛收益和扣佣后收益分别为：
#
# ```
# trade.pnl = (110 - 100) * 10 = 100
# trade.pnlcomm = 100 - 5 = 95
# ```
#
# 当该交易被关闭时，`trade.isclosed` 会被设置为 `True` ¹.
#
# 如果您想了解更多关于 `Backtrader` 的信息，可以参考这篇文章 ¹.
#
# 源: 与必应的对话， 2023/11/4
# (1) Trade - Backtrader. https://www.backtrader.com/docu/trade/.
# (2) backtrader中何为一个交易trade?你可能并没理解它 - CSDN博客. https://blog.csdn.net/qtbgo/article/details/109799469.
# (3) backtrader中何为一个交易trade?你可能并没理解它。 - 知乎. https://zhuanlan.zhihu.com/p/299630905.
# (4) Backtrader中文笔记之Trade(交易) - 就是想学习 - 博客园. https://www.cnblogs.com/sidianok/p/13703966.html.

# %% [markdown]
# 那么backtrader中是如何定义交易的呢？
# 对正常采用自有资金购买股票，不能做空的情况下，当一个订单使得仓位从0变为正值，则打开了一个交易，此后，当某订单使得仓位从正值变为0，则该交易关闭，这两种情况都会触发notify_trade方法。
#
# 一个交易可能由多个订单组成。不能做空的情况下，举个例子观察交易状态的变化，在next方法中：
#
# 第一次下买单买100股，此订单执行时，仓位从0变为正值（100），系统打开一个交易，会触发notify_trade方法，在notify_trade中检查交易状态status，为1 open。
#
# 然后下第二张买单100股，订单执行时不会触发notify_trade，仓位变为200。
#
# 然后下卖单卖100股，仍然不会触发notify_trade，仓位变为100。
#
# 再下一个卖单卖100股，执行时，仓位从100变为0，关闭交易，触发notify_trade，交易状态为2 close。
#
# 不能做空的情况下，self.close()命令会一次性市价卖出全部仓位，关闭交易。
#
# 在可以做空的情况下，当仓位从0变为非0（长仓为正值，短仓为负值），则打开了一个交易，此后仓位从非0值变为0值，则交易关闭。在卖空操作中，self.close()默认会市价买回所有卖空仓位，关闭交易。
#
# 如果某个订单使得仓位从正值变到负值，或负值变到正值，则意味着两个动作：一个交易被关闭了（仓位从非0值变为0），一个新交易被打开了（仓位从0变为非0）。
# ————————————————
# 版权声明：本文为CSDN博主「扫地僧量化」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。
# 原文链接：https://blog.csdn.net/qtbgo/article/details/109799469

# %% [markdown]
# `notify_order` 方法是 `Backtrader` 中的一个回调函数，它会在订单状态发生变化时被调用 ¹. 该方法的默认实现会在订单被提交、接受、完成、取消、拒绝或出现保证金问题时打印出相应的信息 ¹².
#
# 如果您想自定义 `notify_order` 方法，可以在您的策略类中重写该方法。例如，您可以在订单被完成时记录订单的毛收益、扣佣后收益和佣金，如下所示：
#
# ```python
# class MyStrategy(bt.Strategy):
#     def notify_order(self, order):
#         if order.status == order.Completed:
#             if order.isbuy():
#                 self.log('BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' % (order.executed.price, order.executed.value, order.executed.comm))
#             else:
#                 self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' % (order.executed.price, order.executed.value, order.executed.comm))
#             self.bar_executed = len(self)
#         elif order.status in [order.Canceled, order.Margin, order.Rejected]:
#             self.log('Order Canceled/Margin/Rejected')
#         self.order = None
# ```
#
# 在上述代码中，我们重写了 `notify_order` 方法，当订单被完成时，会打印出订单的毛收益、扣佣后收益和佣金 ¹.
#
# 如果您想了解更多关于 `Backtrader` 的信息，可以参考这篇文章 ¹.
#
# 源: 与必应的对话， 2023/11/4
# (1) Backtrader for Backtesting (Python) – A Complete Guide - AlgoTrading101. https://algotrading101.com/learn/backtrader-for-backtesting/.
# (2) Ask on the logic of notify order and next to execute strategy. https://community.backtrader.com/topic/2211/ask-on-the-logic-of-notify-order-and-next-to-execute-strategy.
# (3) Stop-Loss Trading - Backtrader. https://www.backtrader.com/blog/posts/2018-02-01-stop-trading/stop-trading/.
# (4) Backtrader量化平台教程（三）Indicator-腾讯云开发者社区 .... https://cloud.tencent.com/developer/article/1388330.
# (5) Quickstart Guide - Backtrader. https://www.backtrader.com/docu/quickstart/quickstart/.
# (6) Orders - General - Backtrader. https://www.backtrader.com/docu/order/.
# (7) Strategy - Backtrader. https://www.backtrader.com/docu/strategy/.
# (8) Python量化backtrader18：Orders【订单】 - 知乎. https://zhuanlan.zhihu.com/p/365877037.
# (9) github.com. https://github.com/zsalem2023/Backtrader/tree/59b719ebb2d49c70b5fe35e674b3e196524cdc29/Strategies%2FSimpleMovingAverage.py.
# (10) github.com. https://github.com/bolobox/ichibot/tree/9ee7ebe9a7f3b97a11bc5a55e6971f74ce1e366d/app%2Fstrategies%2Fbasestrategy.py.
# (11) github.com. https://github.com/Airwiwin/flouz/tree/4158813d1fde028d6f009121dbd82850d772e96d/hello_backtrader.py.

# %% [markdown]
# `notify_order` 和 `notify_position` 都是 `Backtrader` 中的回调函数，但它们的作用不同 ¹².
#
# `notify_order` 方法会在订单状态发生变化时被调用，例如订单被提交、接受、完成、取消、拒绝或出现保证金问题时 ¹. 该方法的默认实现会在订单状态发生变化时打印出相应的信息 ¹².
#
# `notify_position` 方法会在交易状态发生变化时被调用，例如交易被打开、更新或关闭时 ¹. 该方法的默认实现会在交易状态发生变化时打印出相应的信息 ¹².
#
# 如果您想自定义 `notify_order` 或 `notify_position` 方法，可以在您的策略类中重写这些方法。例如，您可以在订单状态发生变化时记录订单的毛收益、扣佣后收益和佣金，如下所示：
#
# ```python
# class MyStrategy(bt.Strategy):
#     def notify_order(self, order):
#         if order.status == order.Completed:
#             if order.isbuy():
#                 self.log('BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' % (order.executed.price, order.executed.value, order.executed.comm))
#             else:
#                 self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' % (order.executed.price, order.executed.value, order.executed.comm))
#             self.bar_executed = len(self)
#         elif order.status in [order.Canceled, order.Margin, order.Rejected]:
#             self.log('Order Canceled/Margin/Rejected')
#         self.order = None
#
#     def notify_trade(self, trade):
#         if trade.isclosed:
#             self.log('毛收益 %0.2f, 扣佣后收益 % 0.2f, 佣金 %.2f' % (trade.pnl, trade.pnlcomm, trade.commission))
# ```
#
# 在上述代码中，我们重写了 `notify_order` 和 `notify_trade` 方法，当订单被完成时，会打印出订单的毛收益、扣佣后收益和佣金 ¹.
#
# 如果您想了解更多关于 `Backtrader` 的信息，可以参考这篇文章 ¹.
#
# 源: 与必应的对话， 2023/11/4
# (1) Backtrader（十七）-Order订单 - 订单通知_backtrader notify .... https://blog.csdn.net/weixin_44785098/article/details/122681266.
# (2) Backtrader量化平台教程（三）Indicator-腾讯云开发者社区 .... https://cloud.tencent.com/developer/article/1388330.
# (3) backtrader中何为一个交易trade?你可能并没理解它。 - 知乎. https://zhuanlan.zhihu.com/p/299630905.
# (4) MT5中position、order、deal 区别_orders deals positions-CSDN博客. https://blog.csdn.net/xjjatdna/article/details/115796960.
# (5) Python量化交易学习笔记（26）——backtrader的order概述 .... https://blog.csdn.net/m0_46603114/article/details/106031259.
# (6) Orders - General - Backtrader. https://www.backtrader.com/docu/order/.
# (7) Strategy - Backtrader. https://www.backtrader.com/docu/strategy/.
# (8) Stop-Loss Trading - Backtrader. https://www.backtrader.com/blog/posts/2018-02-01-stop-trading/stop-trading/.
# (9) Python量化backtrader18：Orders【订单】 - 知乎. https://zhuanlan.zhihu.com/p/365877037.
# (10) github.com. https://github.com/zsalem2023/Backtrader/tree/59b719ebb2d49c70b5fe35e674b3e196524cdc29/Strategies%2FSimpleMovingAverage.py.
# (11) github.com. https://github.com/Airwiwin/flouz/tree/4158813d1fde028d6f009121dbd82850d772e96d/hello_backtrader.py.
# (12) github.com. https://github.com/bolobox/ichibot/tree/9ee7ebe9a7f3b97a11bc5a55e6971f74ce1e366d/app%2Fstrategies%2Fbasestrategy.py.
# (13) github.com. https://github.com/gejianxin/stock/tree/3a2c15e6a031a1dac3bd4a18b57d94f4980cd076/strategies%2FPolyStrategy.py.
# (14) github.com. https://github.com/zhengxingXue/trading_platform_learning/tree/678e8a1fc9210f5075825a093271ea0fef852c43/backtrader%2Fquickstart_3_simple_moving_average.py.

# %% [markdown]
# `cerebro.addsizer` 是 `Backtrader` 中的一个方法，用于向 `Cerebro` 对象中添加一个交易量调整器（sizer） ¹. 交易量调整器是用于计算每个订单的交易量的对象，它可以根据您的策略和市场情况自动调整交易量 ².
#
# `cerebro.addsizer` 方法有两个参数：
#
# - `sizercls`：交易量调整器的类。
# - `*args` 和 `**kwargs`：传递给交易量调整器的参数。
#
# 例如，如果您想使用 `bt.sizers.FixedSize` 作为交易量调整器，并将交易量设置为 `10`，则可以使用以下代码：
#
# ```python
# cerebro.addsizer(bt.sizers.FixedSize, stake=10)
# ```
#
# 如果您想了解更多关于 `Backtrader` 的信息，可以参考这篇文章 ¹.
#
# 源: 与必应的对话， 2023/11/4
# (1) Sizers - Backtrader. https://www.backtrader.com/docu/sizers/sizers/.
# (2) Backtrader - sizer - iT 邦幫忙::一起幫忙解決難題，拯救 IT .... https://ithelp.ithome.com.tw/articles/10279754.
# (3) backtrader无法满仓交易的问题 - CSDN博客. https://blog.csdn.net/haydengao/article/details/118330186.
# (4) 学习backtrader框架---给策略添加参数、指标的一些注意 .... https://blog.csdn.net/weixin_42612813/article/details/90678446.
# (5) Cerebro - Backtrader. https://www.backtrader.com/docu/cerebro/.

# %% [markdown]
# `cerebro.addsizer` 方法有两个参数：
#
# - `sizercls`：交易量调整器的类。
# - `*args` 和 `**kwargs`：传递给交易量调整器的参数。
#
# 其中，`stake` 和 `percent` 是 `bt.sizers.FixedSize` 和 `bt.sizers.PercentSizer` 两个交易量调整器的参数之一 ⁵.
#
# - `stake`：表示每个订单的交易量，通常是一个整数或浮点数 ⁵.
# - `percent`：表示每个订单的交易量占可用资金的百分比，通常是一个浮点数 ⁵.
#
# 如果您想了解更多关于 `Backtrader` 的信息，可以参考这篇文章 ¹.
#
# 源: 与必应的对话， 2023/11/4
# (1) 量化投资之工具篇：Backtrader从入门到精通（10）交易 .... https://zhuanlan.zhihu.com/p/494061468.
# (2) Cerebro - Backtrader. https://www.backtrader.com/docu/cerebro/.
# (3) 学习backtrader框架---给策略添加参数、指标的一些注意 .... https://blog.csdn.net/weixin_42612813/article/details/90678446.
# (4) How to write your first, simple backtrader strategy - Quant Nomad. https://quantnomad.com/faq-how-to-write-your-first-simple-backtrader-strategy/.
# (5) Sizers - Backtrader. https://www.backtrader.com/docu/sizers/sizers/.
# (6) Sizers - Reference - Backtrader. https://www.backtrader.com/docu/sizers-reference/.
# (7) Backtrader - sizer - iT 邦幫忙::一起幫忙解決難題，拯救 IT .... https://bing.com/search?q=cerebro.addsizer+percent.
# (8) Backtrader - sizer - iT 邦幫忙::一起幫忙解決難題，拯救 IT .... https://ithelp.ithome.com.tw/articles/10279754?sc=hot.
# (9) Backtrader - sizer. http://25230.com/17200404/3831.html.
# (10) Beginner’s Guide to Sizers in Backtrader | by JohnJoy | Medium. https://medium.com/@jesso1908joy/beginners-guide-to-sizers-in-backtrader-6c0ba892fe80.
# (11) Backtrader中文笔记之Sizers - 就是想学习 - 博客园. https://www.cnblogs.com/sidianok/p/13709384.html.

# %% [markdown]
# 您好，这是Bing。感谢您的提问。😊
#
# backtrader是一个Python库，用于进行回测和交易策略的开发和测试¹。backtrader中，一个订单（order）是一个指示买入或卖出某个资产的对象²。一个订单是否仍然存在，取决于它的状态（status）³。
#
# backtrader提供了一个枚举类Order.Status，用于表示订单的不同状态³。这些状态包括：
#
# - Order.Created：订单被创建，但还没有提交到市场。
# - Order.Submitted：订单已经提交到市场，等待被接受或拒绝。
# - Order.Accepted：订单已经被市场接受，等待被执行或取消。
# - Order.Partial：订单已经部分执行，剩余的部分仍然在市场中。
# - Order.Completed：订单已经完全执行，没有剩余的部分。
# - Order.Canceled：订单已经被取消，没有被执行的部分。
# - Order.Margin：订单由于资金不足而被取消。
# - Order.Rejected：订单被市场拒绝，没有被执行。
#
# 根据这些状态，我们可以判断一个订单是否仍然存在的方法是：
#
# - 如果订单的状态是Order.Created，Order.Submitted，Order.Accepted或Order.Partial，那么订单仍然存在，可能会在未来被执行或取消。
# - 如果订单的状态是Order.Completed，Order.Canceled，Order.Margin或Order.Rejected，那么订单已经不存在，不会再有任何变化。
#
# backtrader提供了一些方法和属性，用于获取和修改订单的状态³。例如：
#
# - order.status：返回订单的当前状态。
# - order.cancel()：取消订单，如果订单还没有被执行或取消。
# - order.executed：返回一个对象，包含订单的执行信息，如价格，数量，佣金等。
# - order.isbuy()：返回一个布尔值，表示订单是否是买入。
# - order.issell()：返回一个布尔值，表示订单是否是卖出。
#
# 希望这些信息能够对您有所帮助。如果您还有其他问题，欢迎继续提问。😊
#
# 源: 与必应的对话， 2023/11/5
# (1) Python量化backtrader18：Orders【订单】 - 知乎. https://zhuanlan.zhihu.com/p/365877037.
# (2) Backtrader来啦：交易篇（下） - 知乎. https://zhuanlan.zhihu.com/p/381273223.
# (3) backtrader中何为一个交易trade?你可能并没理解它。 - 知乎. https://zhuanlan.zhihu.com/p/299630905.
# (4) Backtrader（十二）- 订单 Order -buy、sell、close - CSDN博客. https://blog.csdn.net/weixin_44785098/article/details/122647991.

# %% [markdown]
# 您好，这是Bing。感谢您的提问。😊
#
# backtrader是一个用于回测和交易的Python框架，它可以帮助您开发和测试您的交易策略¹。backtrader没有提供一个直接的方法来规定最大回撤，但是您可以使用一些技巧来实现这个功能。
#
# 一种可能的方法是使用`self.broker.getvalue()`来获取当前的账户价值，然后与之前的最高价值进行比较，如果超过了您设定的最大回撤比例，就触发一个信号来平仓或者停止交易²。例如，您可以在您的策略类中定义一个属性`self.max_drawdown`来存储您的最大回撤比例，然后在`next`方法中添加如下的代码：
#
# ```python
# # 获取当前的账户价值
# current_value = self.broker.getvalue()
# # 更新最高价值
# self.high_value = max(self.high_value, current_value)
# # 计算当前的回撤比例
# drawdown_ratio = (self.high_value - current_value) / self.high_value
# # 如果超过了最大回撤比例，就触发一个信号
# if drawdown_ratio > self.max_drawdown:
#     # 平仓或者停止交易的逻辑
#     ...
# ```
#
# 另一种可能的方法是使用`self.analyzers.drawdown.get_analysis()`来获取当前的回测分析结果，然后从中提取当前的回撤比例，如果超过了您设定的最大回撤比例，就触发一个信号来平仓或者停止交易³。例如，您可以在您的策略类中定义一个属性`self.max_drawdown`来存储您的最大回撤比例，然后在`next`方法中添加如下的代码：
#
# ```python
# # 获取当前的回测分析结果
# drawdown_analysis = self.analyzers.drawdown.get_analysis()
# # 提取当前的回撤比例
# drawdown_ratio = drawdown_analysis.drawdown / 100
# # 如果超过了最大回撤比例，就触发一个信号
# if drawdown_ratio > self.max_drawdown:
#     # 平仓或者停止交易的逻辑
#     ...
# ```
#
# 以上是两种可能的方法来规定最大回撤，您可以根据您的具体需求和偏好来选择和调整。希望这些信息对您有所帮助。如果您还有其他问题，欢迎继续提问。😊
#
# 源: 与必应的对话， 2023/11/5
# (1) 量化投资学习笔记73——backtrader实操 - 知乎. https://zhuanlan.zhihu.com/p/158405659.
# (2) BackTrader踩坑记录 - 知乎. https://zhuanlan.zhihu.com/p/616104522.
# (3) backtrader量化回测实践篇 - 知乎. https://zhuanlan.zhihu.com/p/397459857.
# (4) Backtrader快速入门——2. 策略表现评估_backtrader 最大回 .... https://blog.csdn.net/Castlehe/article/details/113772133.

# %% [markdown]
# 在backtrader中，您可以使用`stop`方法来停止交易。`stop`方法是一个回调函数，当策略停止时会被调用。您可以在`stop`方法中添加逻辑来判断是否需要停止交易。例如，您可以在策略类中定义一个属性`self.stop_trading`，并在`stop`方法中检查它的值，如果为`True`，就停止交易。在策略类中，您可以使用`next`方法来处理每个数据点，然后在`next`方法中添加逻辑来判断是否需要停止交易。例如，您可以在`next`方法中计算当前的回撤比例，如果超过了您设定的最大回撤比例，就将`self.stop_trading`设置为`True`，触发停止交易信号。以下是一个示例代码，用于在回测过程中实时监测最大回撤，并在回撤超过最大回撤比例时停止交易：
#
# ```python
# import backtrader as bt
#
# class MyStrategy(bt.Strategy):
#     params = (
#         ('max_drawdown', 0.1),  # 最大回撤比例
#     )
#
#     def __init__(self):
#         self.high_value = self.broker.getvalue()  # 最高价值
#         self.stop_trading = False  # 是否停止交易
#
#     def next(self):
#         current_value = self.broker.getvalue()  # 当前价值
#         drawdown_ratio = (self.high_value - current_value) / self.high_value  # 当前回撤比例
#         if drawdown_ratio > self.params.max_drawdown:
#             self.stop_trading = True  # 触发停止交易信号
#         if not self.position and not self.stop_trading:
#             self.buy()
#         elif self.position and not self.stop_trading:
#             self.sell()
#
#     def stop(self):
#         if self.stop_trading:
#             print('交易已停止，最大回撤超过最大回撤比例')
# ```
#
# 在上面的代码中，我们定义了一个`MyStrategy`策略类，它包括一个`max_drawdown`参数，用于设置最大回撤比例。在`__init__`方法中，我们初始化了`high_value`和`stop_trading`两个变量。`high_value`用于记录当前的最高价值，`stop_trading`用于记录是否停止交易。在`next`方法中，我们首先计算当前的回撤比例，如果超过了最大回撤比例，就将`stop_trading`设置为`True`，触发停止交易信号。如果当前没有持仓且未触发停止交易信号，就发出买入信号；如果当前有持仓且未触发停止交易信号，就发出卖出信号。在`stop`方法中，我们检查是否触发了停止交易信号，如果是，就输出一条消息，表示交易已经停止。
#
# 希望这些信息对您有所帮助。如果您还有其他问题，欢迎继续提问。😊
#
# 源: 与必应的对话， 2023/11/5
# (1) Backtrader来啦：交易篇（下） - 知乎. https://zhuanlan.zhihu.com/p/381273223.
# (2) 【手把手教你】用backtrader量化回测海龟交易策略 - 雪球. https://xueqiu.com/1444657641/154494557.
# (3) backtrader中何为一个交易trade?你可能并没理解它。 - 知乎. https://zhuanlan.zhihu.com/p/299630905.
# (4) Backtrader来啦：交易篇（上） - 知乎. https://zhuanlan.zhihu.com/p/381275772.
# (5) 量化投资之工具篇：Backtrader从入门到精通（8）交易 .... https://zhuanlan.zhihu.com/p/486905723.
# (6) Stop-Loss Trading - Backtrader. https://www.backtrader.com/blog/posts/2018-02-01-stop-trading/stop-trading/.
# (7) Observers - Statistics - Backtrader. https://www.backtrader.com/docu/observers-and-statistics/observers-and-statistics/.
# (8) Backtrader中文笔记之Analyzers Reference - 就是想学习 - 博客园. https://www.cnblogs.com/sidianok/p/13661588.html.

# %% [markdown]
# 在`backtrader`中，`self.broker.getcash()`方法返回的是当前持仓的现金价值。如果你在当天进行了一笔买入交易，那么你的持仓的现金价值会发生变化。具体的计算公式如下：
#
# - 假设你的初始现金为`cash0`，你的交易数量为`size`，你的买入价格为`price`，你的交易佣金为`commission`，那么你的交易成本为`cost = size * price * (1 + commission)`。
# - 假设你的交易发生在当天的开盘时刻，那么你的持仓的现金价值为`cash1 = cash0 - cost`。
# - 假设你的交易发生在当天的收盘时刻，那么你的持仓的现金价值为`cash2 = cash0 - cost + size * close`，其中`close`是当天的收盘价格。
#
# 举一个例子：
#
# - 假设你的初始现金为$10000$，你的交易数量为$100$，你的买入价格为$200$，你的交易佣金为$0.001$，那么你的交易成本为$cost = 100 * 200 * (1 + 0.001) = 20020$。
# - 假设你的交易发生在当天的开盘时刻，那么你的持仓的现金价值为`cash1 = 10000 - 20020 = -8020`。
# - 假设你的交易发生在当天的收盘时刻，且当天的收盘价格为$210$，那么你的持仓的现金价值为`cash2 = 10000 - 20020 + 100 * 210 = 18980`。
#
# 源: 与必应的对话， 2023/11/5
# (1) Broker - Backtrader. https://www.backtrader.com/docu/broker/.
# (2) Kelly Criterion : Backtrader Hacks | by JohnJoy | Medium. https://medium.com/@jesso1908joy/kelly-criterion-backtrader-hacks-c982a67907e2.
# (3) 回测框架 backtrader 怎么获得每一步的cash或value？ - 知乎. https://www.zhihu.com/question/413504483.
# (4) 学习backtrader的捷径-写给backtrader初学者 - 知乎. https://zhuanlan.zhihu.com/p/406717815.

# %% [markdown]
# https://blog.csdn.net/weixin_42612813/article/details/90678446

# %% [markdown]
# 关于cheat on close
# https://zhuanlan.zhihu.com/p/270871069
